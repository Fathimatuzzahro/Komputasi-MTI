# %%
# Header
from numpy import *
import math

# Fungsi - fungsi
def PCA(x, y):
       print ("Fungsi 1")
      
# Program Utama
print ("Program Utama")

# %%
a := 100
a = a + 1
a = b + 1
print a

# %%
print ("2 + 2 adalah"), 2 + 2
print ("3 * 4 adalah"), 3 * 4
print ("100 - 1 adalah"), 100 - 1
print ("(33 + 2) / 5 + 11.5 adalah"), (33 + 2) / 5 + 11.5

# %%
print ("2 + 2 adalah %d", 2 + 2)
print ("3 * 4 adalah %d", 3 * 4)
print ("(33 + 2) / 5 + 11.5 adalah", (33 + 2) / 5 + 11.5)

# %%
print ("2 + 2 adalah %d", 2 + 2)
print ("3 * 4 adalah %d", 3 * 4)
print ("100 - 1 adalah %d", 100 - 1)
print ("(33 + 2) / 5 + 11.5 adalah %f", (33 + 2) / 5 + 11.5)

# %%
# Program 2.1
var_int = 10
var_float = 1.2345
var_str = ("Hello, World!")
print ("Python Style")
print ("Integer =", var_int)
print ("Floating-point =", var_float)
print ("String =", var_str)
print
print ("C style")
print ("Integer = %d", (var_int))
print ("Floating-point = %f", (var_float))
print ("String = %s", (var_str))
print
print ("Kontrol khusus")
print ("Pindah baris dua kali\n")
print ("Nggak pindah baris"),
print ("\tmasih satu baris")

# %%
a = input("Masukkan suatu bilangan =")
a = input("Masukkan suatu bilangan =")

# %%
a = raw_input("Masukkan suatu kata =")
b = float(raw_input("Masukkan suatu bilangan ="))
c = int(raw_input("Masukkan suatu bilangan = "))
print (a, b, c)

# %%
# Program 2.2
kuliah = ("Praktikum Prokom")
nama = raw_input("masukkan nama anda = ")
nrp = input("masukkan nrp anda = ")
print
print ("Selamat datang di mata kuliah", kuliah)

# %%
# program pertama
print ("PRAKTIKUM PEMROGRAMAN KOMPUTER")
print ("Berikut contoh program penambahan")
a = 2
b = 3
hasil = a + b
print ("hasil = a + b")
print ("hasil %d + %d" % (a,b))
print ("hasil %d" % (hasil))

# %%
# Mencari Kesalahan / Debugging
print ("Hello, World!")
print (2 + 2, end= " ")
print ("Test 123")
a = 2 * 4
print ("aa")
